# %% [markdown]
# <a href="https://colab.research.google.com/github/allanfae/Estatistica-para-Ciencia-de-Dados/blob/main/Allan_Bruno_Fa%C3%A9_Projeto_Workflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <?xml version="1.0" encoding="UTF-8"?>
# <html>
#   <body>
#     <header></header>
#         <CENTER>
#           <img src="https://www.uvv.br/wp-content/themes/uvvBr/templates/assets//img/logouvv.svg" alt="UVV-LOGO" style = width="100px"; height="100px">
#         </CENTER>
#         <CENTER><b>DATA SCIENCE PROJECT</b></CENTER><br/>
#         <CENTER><b>WORKFLOW</b></CENTER><br/>

# %% [markdown]
# Link para meu projeto: [Link](https://colab.research.google.com/drive/1RvECo_ABvBzN8vuzmoAWVSNfYsjS-U75?usp=sharing)

# %% [markdown]
# # BIBLIOTECAS E FUNÇÕES

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def statistic(_dataset):
  """
  DOCSTRING:
  Describe (without count) + Insert range: max - min
  """
  _describe = _dataset.describe()
  _describe = _describe.drop('count')
  _describe.loc['range'] = _describe.max() - _describe.min()
  _describe = np.around(_describe.sort_values(), 2)
  return _describe

# %%
def PlotarStatistic(ts, yLabel = None):
  plt.title(f'ESTATÍSTICA DESCRITIVA DO DATASET: Mean ($\mu$) = {ts.mean(): .2f}')
  _describe = statistic(ts)
  ts.agg(statistic).plot(figsize = [15, 6])
  plt.ylabel(yLabel)
  plt.show()
  print('ESTATÍSTICA DESCRITIVA DO DATASET:')
  print(_describe)

# %% [markdown]
# #**Governança de Dados**

# %% [markdown]
# ## <center> **Metodologia: 5W + 2H**

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Referência bibliográfica:**
#
# BARBIERI, Carlos. Governança de dados. [Digite o Local da Editora]: Editora Alta Books, 2020. 9788550815435. E-book. Disponível em: https://integrada.minhabiblioteca.com.br/#/books/9788550815435/. Acesso em: 05 ago. 2022.

# %% [markdown]
# #**Metodologia para Análise de Dados**

# %% [markdown]
# **Para fazer uma análise de dados de forma correta, concisa e que agregue valor ao negócio, é necessário seguir algumas etapas para evitar problemas e extrair resultados ruins, como já diz o ditado:**
#
# <center>
#
#  <FONT COLOR="#0000AA"> **“Dados ruins, Resultados ruins” do inglês “garbage in, garbage out”.**
#
# </center>
#
# **Para isso, já existem algumas metodologias/processos para se fazer análise de dados,**

# %% [markdown]
# ##**2.2 Metodologia para a Etapa de Projeto:**

# %% [markdown]
# **Data Science Workflow: Ciclo de vida:**

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# #**ETAPA 1: ETL - Extract, Transform and Load**

# %% [markdown]
# ## Atividade 1 (A1): Pesquisar o dataset

# %% [markdown]
# **DATASOURCE** - Colocar seu link aqui: [Link](https://www.kaggle.com/code/kmalit/bank-customer-churn-prediction)

# %% [markdown]
# **DATASET** - Colocar seu link aqui: [Link](https://drive.google.com/file/d/1-EZVSKgpVQTeLVfAjaud1suxcdYnPS6L/view?usp=sharing)

# %% [markdown]
# DESCRIÇÃO DAS CARACTERÍSTICAS (**OBRIGATÓRIAS**) DO DATASET:
#
# 1.   Dados (COLUNAS) sobre **BUSINESS**: CLIENTE (primary key) + PRODUTOS ou SERVIÇOS (Desejável) + Coluna (**OBRIGATÓRIA**) de Dinheiro (R$ ou US$ ou qualquer moeda).
# 2.   No mínimo ou acima de **[5000-50000] LINHAS**: Eventos: Clientes + ...
# 2.  **NÃO** é permitido simular os dados de entrada $X$/saída: $/F(X)$ do conjunto.

# %% [markdown]
# ## Atividade 2 (A2): Descrição / Classificação de todas as colunas

# %% [markdown]
# **DESCRIÇÃO:**
#
# *   COLUNA 0: RowNumber
# *   COLUNA 1: CustomerID
# *   COLUNA 2: Sumame
# *   COLUNA 3: Geography
# *   COLUNA 4: Gender
# *   COLUNA 5: HasCrCard
# *   COLUNA 6: IsActiveMember
# *   COLUNA 7: CreditScore
# *   COLUNA 8: Tenure
# *   COLUNA 9: Balance
# *   COLUNA 10: NumOfProducts
# *   COLUNA 11: Age
# *   COLUNA 12: EstimaExitedtedSalary

# %% [markdown]
# **CLASSIFICAÇÃO:**
#
# *   COLUNA 0: RowNumber - Qualitativa Nominal
# *   COLUNA 1: CustomerID -  Qualitativa Nominal
# *   COLUNA 2: Sumame - Qualitativa Nominal
# *   COLUNA 3: Geography -  Qualitativa Nominal
# *   COLUNA 4: Gender - Qualitativa Nominal
# *   COLUNA 5: HasCrCard - Qualitativa Nominal
# *   COLUNA 6: IsActiveMember - Quantitativa Contínua
# *   COLUNA 7: CreditScore - Quantitativa Contínua
# *   COLUNA 8: Tenure - Quantitativa Contínua
# *   COLUNA 9: Balance - Quantitativa Contínua
# *   COLUNA 10: NumOfProducts - Quantitativa Contínua
# *   COLUNA 11: Age - Quantitativa Contínua
# *   COLUNA 12: EstimaExitedtedSalary - Quantitativa Contínua

# %%
import pandas as pd

# %%
dataset = pd.read_csv('/content/Churn_Modelling.csv')

# %%
dataset.head(3)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1

# %%
dataset.shape
# Out:
# (10000, 14)

# %% [markdown]
# #**ETAPA 2: Data Exploration**

# %% [markdown]
# ## Atividade (A1): Definir / Eliminar (DROPAR) colunas **NÃO** relevantes ao Projeto.

# %% [markdown]
# ## Atividade (A2): Pesquisar / Eliminar os Valores duplicados (linhas duplicadas)

# %% [markdown]
# ## Atividade (A3): Pesquisar / Eliminar os Valores de Sentinela (NaN: NotANumber)

# %% [markdown]
# #**ETAPA 3: Data Evoluation**

# %% [markdown]
# ## Análise exploratória das Variáveis Qualitativas

# %% [markdown]
# ### Atividade (A11): Criar os Gráficos (Plotar)

# %% [markdown]
# ### Atividade (A12): Criar as Tabelas: Tabulação Cruzada (Método **crosstab**):
#
# $→$ Incluir uma coluna com valores RELATIVOS (%).

# %% [markdown]
# ## Análise exploratória das Variáveis Quantitativas

# %% [markdown]
# #**ETAPA 4: Data Modeling**

# %% [markdown]
# #**ETAPA 5: Data Presentation**

# %%
# %%shell
# jupyter nbconvert --to html /content/Allan_Bruno_Faé_Projeto_Workflow.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/Allan_Bruno_Faé_Projeto_Workflow.ipynb to html
# [NbConvertApp] Writing 2728014 bytes to /content/Allan_Bruno_Faé_Projeto_Workflow.html
